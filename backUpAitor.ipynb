# %%
import random
from time import sleep
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import os
import pandas as pd
import re

# %% [markdown]
# ## Instalamos el driver de Google y entramos en - ElMundo-SALUD

# %%
#driver = webdriver.Chrome('chromedriver.exe')
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.elmundo.es/ciencia-y-salud.html')
sleep(1.5)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Pablo\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_15524/1013857780.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
listaNoticias = driver.find_elements(By.XPATH, '//a[@class="ue-c-cover-content__link"]')

linkNoticias = list()

for noticia in listaNoticias:
    
    link = noticia.get_attribute('href')
    linkNoticias.append(link)
    
    #print(linkNoticias)

# %%
for i in linkNoticias:
    print(i)
# Out:
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/07/61af421e21efa01b7a8b45ac.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/07/61af53dbfdddff8e368b456d.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/06/61ae4693fc6c8335578b4580.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/08/61afa51021efa0b9448b456d.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/08/61a9fc3ffc6c830e6a8b45d3.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/07/61a913ad21efa0dd428b4585.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/08/61a9f97721efa0dd428b45a3.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/09/61b0e737fc6c838b1d8b45e3.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/05/61aa5667e4d4d8d6748b456f.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/04/61a8d324fc6c8344648b45cb.html
# https://native.elmundo.es/2021/11/16nat/index.html#sec3
# https://www.elmundo.es/uestudio/2021/11/04/6183e4f6fc6c8384768b4665.html
# https://www.elmundo.es/uestudio/2021/11/11/618d34c9fc6c8399578b45d6.html
# https://www.elmundo.es/uestudio/2021/11/10/618b8f92fc6c83be5c8b4597.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/10/61b2e28fc5e20e001eae3a82-directo.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/10/61b2df20e5528d001fffdf39-directo.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/10/61b31168fc6c834b678b45bb.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/10/61b30d35e4d4d8a46b8b456e.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/10/61b25329fdddff1e238b45e2.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/10/61afa1a2fdddffd4458b45b8.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/10/61b1cf92fdddffa2398b458b.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/01/61a75622fc6c83bf678b4580.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b1ff4721efa0311a8b45cc.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b213ebe4d4d8a05a8b45af.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b215f3e4d4d8a4178b45cc.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b20536fdddff4e0e8b45be.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b1f11fe4d4d816368b45b4.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b1e0a1fc6c83e01d8b4599.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b1bf66fc6c8398598b4591.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/09/61b1b6c3fc6c83ad518b45d6.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/09/61b0f62821efa0bd5b8b458d.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/09/61aa53a5fdddff65558b45b8.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/08/61b06b12fc6c83ca768b459f.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/08/61b0b6bae4d4d840478b45b9.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/08/61b0a017fc6c83a81a8b4598.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/08/61afb5cefc6c8391498b45a4.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/08/61af4a52fdddff3d678b4598.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/01/61a7af3efc6c83bf678b45c5.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/07/61af78ca21efa0fe778b45d0.html
# https://native.elmundo.es/2021/12/07re/index.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/11/25/619f4ca6e4d4d84f758b4574.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/07/61aa2963fc6c832d528b45a4.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/06/61ae6392fc6c83b83c8b45bb.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/06/61ae520b21efa0dc7c8b45ad.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/06/61ae2b2321efa0d9248b45a4.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/06/61adf017fc6c83020e8b45bc.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/06/61adbb46fc6c83532f8b45cc.html
# https://www.elmundo.es/ciencia-y-salud/medio-ambiente/2021/12/06/61a8fadbfdddff6f428b4584.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/05/61ac6d0121efa0b83f8b4584.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/04/61ab1cd7fdddffd98f8b4573.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/04/61ab1a47e4d4d8fe268b456d.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/04/61ab16c4e4d4d8ab308b45d4.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61aa775921efa0ff078b45cc.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61aa10cffc6c83f75e8b45cf.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61aa141afdddffdc528b45a6.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61a9073cfc6c83c3568b4600.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61a9c87b21efa0c2258b458a.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/03/61a9f7fffc6c830b1e8b4584.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61a9dbecfc6c835c738b45a2.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/03/61a9b3543cd280001f27d8f4-directo.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/02/61a92a0421efa0e0438b4581.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/01/29/60141474fc6c834e268b4666.html
# https://www.elmundo.es/ciencia-y-salud/ciencia/2021/12/02/61a9274921efa053688b4594.html
# https://www.elmundo.es/ciencia-y-salud/salud/2021/12/02/61a92288e4d4d817408b458c.html

# %%
titulos = list()
entradillas = list()
textos = list()
fechas = list()

for i in linkNoticias:
    
    try:
        driver.get(i)
        titulo = driver.find_element(By.XPATH, '//div[@class="ue-l-article__header-content"]').text
        titulos.append(titulo)
        entradilla = driver.find_element(By.CLASS_NAME, 'ue-c-article__standfirst').text
        entradillas.append(entradilla)
        texto = driver.find_element(By.XPATH, '//div[@class="ue-l-article__body ue-c-article__body"]').text
        textos.append(texto)
        fecha = driver.find_element(By.TAG_NAME, 'time').get_attribute('datetime')
        fechas.append(fecha)
        
        sleep(0.5)
    except:
        continue

# %%
df = pd.DataFrame(list(zip(titulos,entradillas, textos, fechas)), columns = ['Titulos','Entradillas', 'Textos', 'Fechas'])
df=df.assign(Noticiario= "ElMundo")

df["Fechas"] = df["Fechas"].replace(to_replace ='[T]\d*\:\d{2}\:\d{2}[Z]', value = ' ', regex = True)
df
# Out:
#                                               Titulos  \
# 0   SALUD\nEspaña aprueba ampliar la vacunación an...
# 1   COVID Preguntas y respuestas\nAsí será la vacu...
# 2   COVID\nLa vacuna española que quiere ser un es...
# 3   CIENCIA Erupción en La Palma\n80 días a ciegas...
# 4   GEOLOGÍA Entrevista\nSebastián García, vulcanó...
# 5   SALUD\nAsí será un menú del futuro: huevos con...
# 6   CRISIS CLIMÁTICA\nDrones para monitorizar los ...
# 7   MEDIO AMBIENTE\nLa 'guardería' salvaje del cac...
# 8   ASTRONOMÍA Cita con el cielo\nFestival de plan...
# 9   CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 10  COVID\nCoronavirus hoy, última hora en directo...
# 11  SALUD\nSanidad retira un producto en cápsulas ...
# 12  CIENCIA\nHallan en La Rioja al tercer dinosaur...
# 13  CIENCIA Erupción en Cumbre Vieja\n¿Sin volcán ...
# 14  SALUD\nEl macrobrote de Málaga, una voz de ala...
# 15  ACCIONES ANTE LA CRISIS CLIMÁTICA (Y VII)\nJav...
# 16  CERTIFICADO COVID En cada comunidad\nAsí se us...
# 17  COVID-19 Seguimiento de la pandemia\nLa incide...
# 18  SALUD\nLa Agencia Europea del Medicamento dice...
# 19  SALUD\nLa OMS confirma que los datos de las va...
# 20  SALUD\n¿Por qué duelen los huesos con la edad ...
# 21  SALUD\nInvestigadoras del CSIC identifican una...
# 22  SALUD\nLa FDA da luz verde a la inmunización c...
# 23  SALUD\nNueva Zelanda presenta un plan para pro...
# 24  CIENCIA\nUn vehículo espacial chino explorará ...
# 25  COVID\n¿Cómo han cambiado las vacunas el día a...
# 26  FORO\nEspaña se queda sin agua: 27 millones de...
# 27  SALUD\nSanidad quiere prohibir fumar en coches...
# 28  SALUD\nPfizer asegura que tres dosis de su vac...
# 29  SALUD\nAdiós a los prospectos de medicamentos ...
# 30  SALUD\nEl 60% de las vacunas infantiles contra...
# 31  COVID-19 Seguimiento de la pandemia\nLa ocupac...
# 32  PREMIO\nIsabel Munera, galardonada con el IV P...
# 33  ESTUDIO\nDemostrado: sí es posible evitar el b...
# 34  VACUNA NIÑOS Vacunación\nPreguntas y respuesta...
# 35  BOTICARIA GARCÍA Consultorio\nAfrontamos la nu...
# 36  COVID\n¿Es más eficaz la vacuna de Pfizer o la...
# 37  CIENCIA\nUn segundo cono crece "a gran velocid...
# 38  SALUD\nLa EMA respalda el uso de tocilizumab e...
# 39  SALUD\nHallan el ácido nucleico que "bloquea" ...
# 40  CORONAVIRUS\nLas tres hipótesis de los científ...
# 41  ENERGÍA\nLa luz vuelve a dispararse a las puer...
# 42  CORONAVIRUS\n¿Y si ómicron fuera la variante q...
# 43  CORONAVIRUS\nVla2001, la nueva vacuna que estu...
# 44  CORONAVIRUS\n¿Por qué se necesitará una vacuna...
# 45  CORONAVIRUS\n¿Quién es el hombre que usó un br...
# 46  SALUD Coronavirus\nSanidad insiste en recomend...
# 47  SALUD\nLa incidencia sube otros 14 puntos hast...
# 48  ITALIA\nDenunciado por intentar vacunarse del ...
# 49  SALUD\nEl refuerzo con las diferentes vacunas ...
# 50  SALUD\nEl portuario antivacunas hospitalizado ...
# 51  CIENCIA\nCalendario lunar diciembre 2021: las ...
# 52  SALUD\nEl riesgo de reinfección para las perso...
# 53  COVID\nCoronavirus hoy, última hora en directo...
# 54  COVID-19 Variantes\nÓmicron, "un virus más esc...
#
#                                           Entradillas  \
# 0   La ministra de Sanidad, Carolina Darias, ha ap...
# 1   La inmunización que está desarrollando el labo...
# 2   El volcán de Cumbre Vieja está a sólo cuatro d...
# 3   El director del Observatorio de Vigilancia Vol...
# 4   La "innovación invisible" empuja ya a la indus...
# 5   Científicos chinos han puesto en funcionamient...
# 6   Un equipo de científicos documenta por tercer ...
# 7   La superficie afectada por la lava del volcán ...
# 8   El nuevo semáforo Covid de Sanidad sitúa ahora...
# 9   En un comunicado, la AEMPS explica que este pr...
# 10  Los rastros fósiles analizados se localizan en...
# 11  Los datos sugieren que podría parar en las pró...
# 12  Después de los más de 80 contagiados tras una ...
# 13  Desde Alpedrete, armado con un móvil y con "re...
# 14  Cada vez más comunidades autónomas recurren al...
# 15  Sanidad también notifica 84 muertes y 26.412 c...
# 16  El organismo europeo también señala que, aunqu...
# 17  La directora del Departamento de Inmunización ...
# 18  De pronto, nos molestan las rodillas y nos cue...
# 19  La bacteria intestinal del género Holdemanella...
# 20  EEUU autoriza la combinación de anticuerpos mo...
# 21  A partir de 2027 aumentarán la edad mínima par...
# 22  El vehículo lunar Yutu 2, que comenzó una expe...
# 23  Es el tercer curso con el Covid como compañero...
# 24  El cambio climático y el déficit estructural d...
# 25  El Gobierno acaba de enviar el borrador de su ...
# 26  Los laboratorios anuncian que van a desarrolla...
# 27  En enero de 2022 se pondrá en marcha un 'pilot...
# 28  El 13 de diciembre se recibirá una primera par...
# 29  Con una subida hasta 290, España se acerca al ...
# 30  El texto ofrece "un análisis detallado de los ...
# 31  Al menos un 30% de las embarazadas con alto ri...
# 32  Desde la Sociedad Española de Farmacia Hospita...
# 33  El fantasma de las navidades pasadas ha vuelto...
# 34  En la primera comparación directa de la eficac...
# 35  Cuando el cono principal comenzó a dar señales...
# 36  Se indica en casos en los que el enfermo esté ...
# 37  El estudio de tres científicos del Instituto I...
# 38  Las mutaciones pueden haberse acumulado en un ...
# 39  El precio del megavatio hora ha sumado 17 días...
# 40  Ómicron, la nueva variante altamente contagios...
# 41  Se llama Vla2001 y se basa en una tecnología y...
# 42  "Las variantes son la peculiaridad de este vir...
# 43  Tiene 57 años y ya había sido suspendido por n...
# 44  La actualización de riesgos difundida este vie...
# 45  Sanidad también notifica 13.738 contagios y 37...
# 46  El hombre intentó engañar a la enfermera para ...
# 47  El refuerzo con las vacunas Covid-19 es seguro...
# 48  Este hombre de 47 años que se encuentra hospit...
# 49  Consulta el calendario lunar de diciembre 2021...
# 50  Se ha detectado un aumento en Sudáfrica de las...
# 51  En Sudáfrica, la nueva variante del coronaviru...
# 52  La alta transmisibilidad de la variante precis...
# 53  España inició el pasado 27 de diciembre la cam...
# 54  El análisis preliminar de los datos que esboza...
#
#                                                Textos                Fechas  \
# 0   Vacuna Así será la vacunación en niños de 5 a ...  2021-12-07T12:37:26Z
# 1   PREMIUM\nCRISTINA G. LUCIO\nMadrid\nActualizad...  2021-12-06T21:47:40Z
# 2   Ciencia ¿Un volcán hasta Navidad? Los expertos...  2021-12-08T01:35:43Z
# 3   PREMIUM\nTERESA GUERRERO\n@teresaguerrerof\nMa...  2021-12-08T14:07:59Z
# 4   ¿Qué comeremos en el futuro? Hace unas décadas...  2021-12-07T13:49:36Z
# 5   Crisis climática El glaciar de Monte Perdido: ...  2021-12-08T00:06:01Z
# 6   "Los cachalotes ayudan a mitigar el cambio cli...  2021-12-09T08:53:30Z
# 7   Ciencia ¿Sin volcán en 2022? "Todos los indici...  2021-12-10T10:14:01Z
# 8   Covid El macrobrote de Málaga, una voz de alar...  2021-12-10T10:20:59Z
# 9   La Agencia Española de Medicamentos y Producto...  2021-12-10T08:36:18Z
# 10  Algunas de las especies de dinosaurios más vel...  2021-12-10T08:18:01Z
# 11  Ciencia 80 días a ciegas frente al volcán: "Lo...  2021-12-10T08:13:47Z
# 12  Brote Los 68 profesionales infectados en el br...  2021-12-10T00:51:28Z
# 13  Antonio Abellán El agitador de la huerta murci...  2021-12-10T00:10:07Z
# 14  PERE ÍÑIGO\nMadrid\nEL MUNDO GRÁFICOS\n@elmund...  2021-12-09T20:17:09Z
# 15  Directo Coronavirus hoy\nEEUU La FDA da luz ve...  2021-12-09T18:08:52Z
# 16  Directo Últimas noticias del coronavirus\nVacu...  2021-12-09T15:41:01Z
# 17  Directo Últimas noticias sobre el coronavirus\...  2021-12-09T14:43:04Z
# 18  Patología Artrosis, la enfermedad que sufre Ma...  2021-12-09T14:03:01Z
# 19  Estudio Cuando la diabetes tipo 2 se 'esfuma' ...  2021-12-09T12:21:49Z
# 20  Covid-19 Los anticuerpos de AstraZeneca reduce...  2021-12-09T10:57:54Z
# 21  Salud Nueva Zelanda estudia prohibir el tabaco...  2021-12-09T08:33:50Z
# 22  Espacio Las primeras huellas de China en la Lu...  2021-12-09T07:56:56Z
# 23  PREMIUM\nGRACIA PABLOS\nActualizado Jueves, 9 ...  2021-12-09T04:47:18Z
# 24  El vaso de agua en España está medio vacío. La...  2021-12-09T00:11:51Z
# 25  El Ministerio de Sanidad prevé prohibir fumar ...  2021-12-08T16:56:27Z
# 26  En vivo Toda la última hora del coronavirus\nC...  2021-12-08T15:29:31Z
# 27  La Agencia Española de Medicamentos y Producto...  2021-12-08T12:07:56Z
# 28  En vivo Coronavirus, España, hoy\nPyR Así será...  2021-12-08T01:35:40Z
# 29  Directo Coronavirus hoy\nPreguntas y respuesta...  2021-12-07T23:28:31Z
# 30  Ecoalf, Lolo Carolo, Ray Musgo... España asalt...  2021-12-07T16:45:28Z
# 31  Riesgo La contaminación ambiental influye en e...  2021-12-07T16:04:30Z
# 32  Directo Última hora sobre el coronavirus\nPand...  2021-12-07T12:15:45Z
# 33  Día mundial VIH, así se previene la infección ...  2021-12-07T01:48:00Z
# 34  Última hora Coronavirus hoy, última hora en di...  2021-12-06T19:25:17Z
# 35  Ciencia Antes y después: esta visualización mu...  2021-12-06T18:15:15Z
# 36  En vivo Coronavirus, España, hoy\nÓmicron Lo q...  2021-12-06T15:25:53Z
# 37  Covid Las tres hipótesis de los científicos so...  2021-12-06T11:14:31Z
# 38  Covid ¿Y si ómicron fuera la variante que la c...  2021-12-06T07:27:06Z
# 39  El precio de la luz vuelve a dispararse a las ...  2021-12-06T00:42:25Z
# 40  Salud Ómicron: lo que sabemos (y lo que no) so...  2021-12-05T07:40:57Z
# 41  Coronavirus ¿Por qué se necesitará una vacuna ...  2021-12-04T07:46:49Z
# 42  Fraude ¿Quién es el hombre que usó un brazo de...  2021-12-04T07:35:49Z
# 43  Italia Denunciado por intentar vacunarse del C...  2021-12-04T07:20:40Z
# 44  Directo Últimas noticias sobre el coronavirus\...  2021-12-03T20:06:34Z
# 45  Directo Coronavirus hoy\nInmunización El refue...  2021-12-03T17:15:11Z
# 46  Sucesos Muere de Covid un antivacunas austriac...  2021-12-03T12:57:04Z
# 47  Directo Últimas noticias del coronavirus\nVacu...  2021-12-03T11:59:43Z
# 48  Directo Últimas noticias del coronavirus\nSuce...  2021-12-03T11:24:32Z
# 49  Astronomía Cómo ver este sábado el eclipse sol...  2021-12-03T10:57:21Z
# 50  Directo Toda la última hora del coronavirus\nC...  2021-12-03T09:16:41Z
# 51  Autonomías Así se usa el pasaporte Covid en Es...  2021-12-05T06:08:05Z
# 52                                                     2021-12-02T21:35:45Z
# 53  Gráficos. Así avanza el Covid-19 y la vacunaci...  2021-12-02T20:29:03Z
# 54  En vivo Última hora del volcán\nLa erupción de...  2021-12-02T20:10:55Z
#
#    Noticiario
# 0     ElMundo
# 1     ElMundo
# 2     ElMundo
# 3     ElMundo
# 4     ElMundo
# 5     ElMundo
# 6     ElMundo
# 7     ElMundo
# 8     ElMundo
# 9     ElMundo
# 10    ElMundo
# 11    ElMundo
# 12    ElMundo
# 13    ElMundo
# 14    ElMundo
# 15    ElMundo
# 16    ElMundo
# 17    ElMundo
# 18    ElMundo
# 19    ElMundo
# 20    ElMundo
# 21    ElMundo
# 22    ElMundo
# 23    ElMundo
# 24    ElMundo
# 25    ElMundo
# 26    ElMundo
# 27    ElMundo
# 28    ElMundo
# 29    ElMundo
# 30    ElMundo
# 31    ElMundo
# 32    ElMundo
# 33    ElMundo
# 34    ElMundo
# 35    ElMundo
# 36    ElMundo
# 37    ElMundo
# 38    ElMundo
# 39    ElMundo
# 40    ElMundo
# 41    ElMundo
# 42    ElMundo
# 43    ElMundo
# 44    ElMundo
# 45    ElMundo
# 46    ElMundo
# 47    ElMundo
# 48    ElMundo
# 49    ElMundo
# 50    ElMundo
# 51    ElMundo
# 52    ElMundo
# 53    ElMundo
# 54    ElMundo

# %%
n_Noticia = 0
for i in df.index:
    nombreFichero = "SALUD_"+ df["Noticiario"][i] + str(n_Noticia)
    file = open(nombreFichero, "w")
    file.write(df["Titulos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Entradillas"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Textos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Fechas"][i]+ "\n")
    sleep(0.5)
    file.close()
    
    n_Noticia += 1
    
    #print("NOTICIA-->"+ df["Titulos"][i]+ "\n"+ df["Entradillas"][i] + df["Textos"][i])

# %% [markdown]
# ## ElMundo-Tecnología

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.elmundo.es/tecnologia.html')
sleep(1.5)

listaNoticiasTech = driver.find_elements(By.XPATH, '//a[@class="ue-c-cover-content__link"]')

linkNoticiasTech = list()

for noticia in listaNoticiasTech:
    
    linkTech = noticia.get_attribute('href')
    linkNoticiasTech.append(linkTech)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\34674\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
titulosTech = list()
entradillasTech = list()
textosTech = list()
fechasTech = list()

for i in linkNoticiasTech:
    
    try:
        driver.get(i)
        titulo = driver.find_element(By.XPATH, '//div[@class="ue-l-article__header-content"]').text
        titulosTech.append(titulo)
        entradilla = driver.find_element(By.CLASS_NAME, 'ue-c-article__standfirst').text
        entradillasTech.append(entradilla)
        texto = driver.find_element(By.XPATH, '//div[@class="ue-l-article__body ue-c-article__body"]').text
        textosTech.append(texto)
        fecha = driver.find_element(By.TAG_NAME, 'time').get_attribute('datetime')
        fechasTech.append(fecha)
        
        sleep(0.5)
    except:
        continue

# %%
df = pd.DataFrame(list(zip(titulosTech,entradillasTech, textosTech, fechasTech)), columns = ['Titulos','Entradillas', 'Textos', 'Fechas'])
df=df.assign(Noticiario= "ElMundo")

df["Fechas"] = df["Fechas"].replace(to_replace ='[T]\d*\:\d{2}\:\d{2}[Z]', value = ' ', regex = True)
df
# Out:
#                                               Titulos  \
# 0   TECNOLOGÍA\nLos mejores regalos en tecnología ...
# 1   VIDEOJUEGOS\nThe Game Awards 2021: It Takes Tw...
# 2   TECNOLOGÍA\nEl volcán de La Palma, la Eurocopa...
# 3   TECNOLOGÍA\nNo hay escapatoria: Apple seguirá ...
# 4   TECNOLOGÍA\nTecnología a muy buen precio para ...
# 5   TECNOLOGÍA\nGoogle bloquea una red de ciberdel...
# 6   TECNOLOGÍA\nNueva estafa de WhatsApp: así te p...
# 7   GADGETS\nOracle Touch: ¿qué puede hacer una ca...
# 8   TECNOLOGÍA\nPrime, Ring y otras aplicaciones d...
# 9   GADGETS\nTeclado y ratón de gaming para los 'n...
# 10  TECNOLOGÍA\nFacebook acaba con una red de acos...
# 11  TECNOLOGÍA\n'Llorar de alegría' se mantiene co...
# 12  TECNOLOGÍA\nPixel Watch: Google trabaja en su ...
# 13  TECNOLOGÍA\nWindows volverá a los ordenadores ...
# 14  TECNOLOGÍA\nEl año de los grandes ciberataques...
# 15  TECNOLOGÍA\nAsí es el procesador que llevarán ...
# 16  TECNOLOGÍA\nLo más visto en Youtube España en ...
# 17  WORKING PROGRESS España y Portugal\nUniversia ...
# 18  REDES SOCIALES\nTwitter prohíbe compartir foto...
# 19  TECNOLOGÍA\nLas gafas de realidad virtual de A...
# 20  VIDEOJUEGOS\nPokémon Unite, elegido el mejor j...
# 21  TECNOLOGÍA\nUna coalición de empresas europeas...
# 22  CREADORES\nAsí es la vida del ex-CEO de Twitte...
# 23  TECNOLOGÍA\nCybermonday 2021: ofertas y descue...
# 24  WORKING PROGRESS CIBERSEGURIDAD\nCómo proteger...
# 25  WORKING PROGRESS Investigación\nComputación cu...
# 26  TECNOLOGÍA\nCybermonday 2021: el último día de...
# 27  TECNOLOGÍA\nCyber Monday 2021: estos son los m...
# 28  TECNOLOGÍA\nCyber Monday 2021: las nuevas ofer...
# 29  Black Friday 2021 en directo: estas son los me...
# 30  TECNOLOGÍA\nBlack Friday 2021: estas son las m...
# 31  GADGETS\nLas mejores ofertas y chollos del Bla...
# 32  TECNOLOGÍA\nBlack Friday 2021: las mejores ofe...
# 33  TECNOLOGÍA\nBlack Friday 2021: las mejores ofe...
# 34  TECNOLOGÍA\nBlack Friday 2021 en Amazon: Estas...
# 35  WORKING PROGRESS Competición\nEl talento digit...
# 36  TECNOLOGÍA\nBlack Friday 2021: las mejores ofe...
# 37  VIDEOJUEGOS\nUn nuevo escándalo sacude a la em...
# 38  TECNOLOGÍA\nBlack Friday: las mejores ofertas ...
# 39  TECNOLOGÍA\nBlack Friday: Las mejores ofertas ...
# 40  BLACK FRIDAY Ránking\nEstos son los 10 móviles...
# 41  TECNOLOGÍA\nArranca la semana del Black Friday...
# 42  VIDEOJUEGOS\nBlack Friday: Las mejores ofertas...
# 43  TECNOLOGÍA\nLas mejores ofertas del Black Frid...
# 44  GADGETS\nBlack Friday 2021: Fire TV Stick 4K M...
# 45  TECNOLOGÍA\nCafetera de alta tecnología: así e...
# 46  TECNOLOGÍA\nApple pide a la Comisión Europea q...
# 47  TECNOLOGÍA\nBlack Friday 2021: las mejores ofe...
# 48  CREADORES\nUna coalición de fiscales de EEUU i...
# 49  TECNOLOGÍA\nSpotify recupera las letras de las...
# 50  INNOVACIÓN 15 y 16 de diciembre\nValencia Digi...
# 51  VIDEOJUEGOS\nAnálisis | Pokémon Perla Relucien...
# 52  GADGETS\nApple da un giro de 180 grados y perm...
# 53  TECNOLOGÍA\nWhatsApp cambia de look: así es la...
# 54  TECNOLOGÍA\nQualcomm lanzará sus propios chips...
# 55  TECNOLOGÍA\nIBM supera la barrera de los 100 c...
#
#                                           Entradillas  \
# 0   Si está pensando en tener un detalle tecnológi...
# 1   Los premios The Game Awards 2021 se han entreg...
# 2   Otras búsquedas populares han sido el Black Fr...
# 3   El plan de la compañía es seguir cobrando esta...
# 4   No hace falta arruinarse para hacer un buen re...
# 5   La compañía señala, que los ciberdelincuentes ...
# 6   Los ciberestafadores envían un correo electrón...
# 7   El precio de las cafeteras de alta gama que im...
# 8   Amazon afirma que la interrupción que ha afect...
# 9   Cada vez que Razer mete la patita en el mundil...
# 10  A su vez, han eliminado una red dedicada a la ...
# 11  El segundo emoji más utilizado es el del coraz...
# 12  Al igual que Apple, Google quiere tener su pro...
# 13  Los nuevos Mac con procesadores M1 no son comp...
# 14  Solo en España se han dado de media 40.000 cib...
# 15  Snapdragon 8 Gen 1 será el sustituto del Snapd...
# 16  ¿Qué es lo que más han visto los españoles en ...
# 17  Desde hoy y hasta mañana 2 de diciembre, Unive...
# 18  Aclaró que esta medida no se aplica a "figuras...
# 19  Apple lleva años trabajando en un visor de rea...
# 20  Google ha compartido un año más los mejores ju...
# 21  La coalición ha denunciado que Microsoft "pres...
# 22  Jack Dorsey ha dejado la dirección de Twitter,...
# 23  Ya se acaban las ofertas del Black Friday y el...
# 24  'Singles Day', Black Friday, Navidad... Noviem...
# 25  Juan Ignacio Cirac, uno de los grandes precurs...
# 26  Las ofertas del Black Friday y el Cybermonday ...
# 27  El Black Friday ya ha pasado. Sin embargo, las...
# 28  Una vez se acaba el Black Friday, llega el Cyb...
# 29  Desde Pixel te presentamos una selección con l...
# 30  El Black Friday 2021 ha llegado. Aquí te ofrec...
# 31  En este artículo te mostramos una selección de...
# 32  Mañana es el Black Friday, pero las ofertas má...
# 33  Si tienes que renovar tu televisor y no quiere...
# 34  Te presentamos la lista de los productos más v...
# 35  Banco Santander y Universia lanzan la primera ...
# 36  Los grandes descuentos hacen que el Black Frid...
# 37  El CEO de Activision Blizzard, Bobby Kotick, r...
# 38  Si tienes que renovar auriculares o quieres da...
# 39  El Black Friday ya está aquí y hay un buen mon...
# 40  La OCU pone a prueba la duración real de las b...
# 41  Comienza la semana del Black Friday y en este ...
# 42  Las rebajas del Black Friday ya están aquí y h...
# 43  Para disfrutar de algunos de los grandes choll...
# 44  El Fire TV Stick 4K Max básicamente aglutina t...
# 45  Sage Appliances ha presentado un nuevo product...
# 46  La medida choca con los intereses de Apple, qu...
# 47  El pistoletazo de salida oficial de las oferta...
# 48  El grupo se está centrando en "las técnicas ut...
# 49  El servicio de música en streaming se ha asoci...
# 50  El encuentro posiciona a la Comunidad Valencia...
# 51  Los nuevos juegos de Pokémon para Switch son r...
# 52  Es la primera vez que Apple, conocida por su g...
# 53  El diseño de la app de WhatsApp para PC y para...
# 54  Los procesadores diseñados por Apple han dado ...
# 55  Esta hazaña debe abrir la puerta al desarrollo...
#
#                                                Textos                Fechas  \
# 0   Sabemos que muchos siguen de resaca por el Bla...  2021-12-10T00:51:35Z
# 1   Móviles Pokémon Unite, elegido el mejor juego ...  2021-12-10T10:54:54Z
# 2   Seguridad Google bloquea una red de ciberdelin...  2021-12-09T08:49:28Z
# 3   El juicio que ha enfrentado a Apple con Epic t...  2021-12-08T17:34:19Z
# 4   Puede que hayas comprado lo que necesitabas en...  2021-12-03T00:55:49Z
# 5   Cibercrimen Así es Void Balaur, el grupo de ha...  2021-12-08T00:00:03Z
# 6   Novedades Así son las 7 nuevas funciones de Wh...  2021-12-06T01:22:05Z
# 7   La respuesta corta a la pregunta que plantea e...  2021-12-07T19:40:59Z
# 8   Varios servicios de Amazon.com Inc, incluido P...  2021-12-07T19:24:02Z
# 9   Medio ambiente Razer lanza nuevos productos de...  2021-12-05T16:45:08Z
# 10  Cambio de nombre Por qué Facebook ahora se lla...  2021-12-04T01:00:33Z
# 11  Trucos Memojis: cómo hacer tus emojis personal...  2021-12-03T10:52:30Z
# 12  Análisis Apple Watch Series 7: pocos cambios, ...  2021-12-03T08:41:37Z
# 13  Apple Sus gafas de realidad virtual llegarán a...  2021-12-02T01:13:16Z
# 14  Seguridad Un ciberataque tumba los servicios d...  2021-12-01T16:28:29Z
# 15  Es muy pronto aun para saber cómo serán los me...  2021-12-01T11:09:24Z
# 16  Polémica YouTube ocultará los 'no me gusta' de...  2021-12-01T09:27:27Z
# 17  Desde hoy 1 de diciembre y hasta mañana, Unive...  2021-12-01T06:00:00Z
# 18  Jack Dorsey El consejero delegado de Twitter, ...  2021-11-30T22:35:31Z
# 19  Justicia Apple no consigue frenar la sentencia...  2021-11-30T08:23:09Z
# 20  El título de combates Pokémon Unite se ha coro...  2021-11-30T00:00:00Z
# 21  Una coalición de empresas de 'software' y 'clo...  2021-11-30T00:00:00Z
# 22  Creadores La desquiciada cuarentena de Elon Mu...  2021-11-29T17:42:36Z
# 23  Black Friday Cybermonday 2021: el último día d...  2021-11-29T13:57:27Z
# 24  IA Gestores de flotas de robots: los jefes de ...  2021-11-29T07:48:38Z
# 25  Juan Ignacio Cirac es de esos investigadores a...  2021-11-29T06:00:00Z
# 26  El Black Friday ya se ha ido y hoy llega el Cy...  2021-11-29T01:12:15Z
# 27  Aunque el Black Friday 2021 ya ha llegado a su...  2021-11-28T00:14:28Z
# 28  Rebajas Black Friday 2021: estas son las mejor...  2021-11-27T00:41:29Z
# 29  Black Friday 2021 Estas son las mejores oferta...  2021-11-26T17:46:20Z
# 30  Black Friday 2021 Estas son las ofertas de tec...  2021-11-26T13:35:24Z
# 31  Black Friday 2021 Estas son las ofertas de tec...  2021-11-25T14:17:40Z
# 32  Black Friday 2021 Estas son las ofertas de tec...  2021-11-25T00:58:10Z
# 33  Cambiar de televisor puede ser un fastidio. Ta...  2021-11-24T14:13:55Z
# 34  Black Friday 2021 Arranca la semana de las ofe...  2021-11-24T08:26:28Z
# 35  El talento digital es un activo al alza. Las e...  2021-11-24T06:00:00Z
# 36  Black Friday 2021 Arranca la semana del Black ...  2021-11-23T12:59:38Z
# 37  Los empleados de Activison Blizzard han vuelto...  2021-11-23T08:07:41Z
# 38  Rebajas Arranca la semana del Black Friday: es...  2021-11-23T01:02:06Z
# 39  Rebajas Las mejores ofertas del Black Friday p...  2021-11-22T13:36:54Z
# 40  Gadgets Black Friday 2021: las mejores ofertas...  2021-11-22T08:21:20Z
# 41  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-21T23:00:10Z
# 42  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-21T01:12:46Z
# 43  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-20T00:58:41Z
# 44  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-19T13:12:21Z
# 45  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-19T09:39:26Z
# 46  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-19T08:04:44Z
# 47  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-19T01:03:27Z
# 48  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T21:20:44Z
# 49  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T18:41:53Z
# 50  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T09:05:14Z
# 51  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T08:38:34Z
# 52  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T07:57:23Z
# 53  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-18T07:56:10Z
# 54  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-17T08:53:13Z
# 55  Tecnología\nGadgets, virus, empresas tecnológi...  2021-11-17T06:33:49Z
#
#    Noticiario
# 0     ElMundo
# 1     ElMundo
# 2     ElMundo
# 3     ElMundo
# 4     ElMundo
# 5     ElMundo
# 6     ElMundo
# 7     ElMundo
# 8     ElMundo
# 9     ElMundo
# 10    ElMundo
# 11    ElMundo
# 12    ElMundo
# 13    ElMundo
# 14    ElMundo
# 15    ElMundo
# 16    ElMundo
# 17    ElMundo
# 18    ElMundo
# 19    ElMundo
# 20    ElMundo
# 21    ElMundo
# 22    ElMundo
# 23    ElMundo
# 24    ElMundo
# 25    ElMundo
# 26    ElMundo
# 27    ElMundo
# 28    ElMundo
# 29    ElMundo
# 30    ElMundo
# 31    ElMundo
# 32    ElMundo
# 33    ElMundo
# 34    ElMundo
# 35    ElMundo
# 36    ElMundo
# 37    ElMundo
# 38    ElMundo
# 39    ElMundo
# 40    ElMundo
# 41    ElMundo
# 42    ElMundo
# 43    ElMundo
# 44    ElMundo
# 45    ElMundo
# 46    ElMundo
# 47    ElMundo
# 48    ElMundo
# 49    ElMundo
# 50    ElMundo
# 51    ElMundo
# 52    ElMundo
# 53    ElMundo
# 54    ElMundo
# 55    ElMundo

# %%
n_Noticia = 0
for i in df.index:
    nombreFichero = "Tecnologia_"+ df["Noticiario"][i] + str(n_Noticia)
    file = open(nombreFichero, "w")
    file.write(df["Titulos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Entradillas"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Textos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Fechas"][i]+ "\n")
    sleep(0.5)
    file.close()
    
    n_Noticia += 1

# %% [markdown]
# ## ELMundo-Ciencia

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.elmundo.es/ciencia-y-salud/ciencia.html')
sleep(1.5)

listaNoticiasSci = driver.find_elements(By.XPATH, '//a[@class="ue-c-cover-content__link"]')

linkNoticiasSci = list()

for noticia in listaNoticiasSci:
    linkSci = noticia.get_attribute('href')
    linkNoticiasSci.append(linkSci)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\34674\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
titulosSci = list()
entradillasSci = list()
textosSci = list()
fechasSci = list()

for i in linkNoticiasSci:
    
    try:
        driver.get(i)
        titulo = driver.find_element(By.XPATH, '//div[@class="ue-l-article__header-content"]').text
        titulosSci.append(titulo)
        entradilla = driver.find_element(By.CLASS_NAME, 'ue-c-article__standfirst').text
        entradillasSci.append(entradilla)
        texto = driver.find_element(By.XPATH, '//div[@class="ue-l-article__body ue-c-article__body"]').text
        textosSci.append(texto)
        fecha = driver.find_element(By.TAG_NAME, 'time').get_attribute('datetime')
        fechasSci.append(fecha)
        
        sleep(0.5)
    except:
        continue

# %%
df = pd.DataFrame(list(zip(titulosSci, entradillasSci, textosSci, fechasSci)), columns = ['Titulos','Entradillas', 'Textos', 'Fechas'])
df=df.assign(Noticiario= "ElMundo")

df["Fechas"] = df["Fechas"].replace(to_replace ='[T]\d*\:\d{2}\:\d{2}[Z]', value = ' ', regex = True)
df
# Out:
#                                               Titulos  \
# 0   CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 1   CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 2   ASTRONOMÍA Crónicas del Cosmos\nLa pareja más ...
# 3   CIENCIA\nCalendario lunar diciembre 2021: las ...
# 4   CIENCIA\nHallan en La Rioja al tercer dinosaur...
# 5   CIENCIA Erupción en Cumbre Vieja\n¿Sin volcán ...
# 6   CIENCIA\nUn vehículo espacial chino explorará ...
# 7   GEOLOGÍA Entrevista\nSebastián García, vulcanó...
# 8   CIENCIA Erupción en La Palma\n80 días a ciegas...
# 9   CIENCIA\nUn segundo cono crece "a gran velocid...
# 10  ASTRONOMÍA Cita con el cielo\nFestival de plan...
# 11  VOLCÁN LA PALMA\nLa erupción en Cumbre Vieja l...
# 12  CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 13  PALEONTOLOGÍA Cubiertas por ceniza volcánica\n...
# 14  ERUPCIÓN EN LA PALMA\nEl futuro de un volcán '...
# 15  Volcán La Palma, última hora en directo | El c...
# 16  DART\nDespega la primera nave espacial de la N...
# 17  CIENCIA Defensa planetaria activa\nDART: así e...
# 18  CIENCIA\nVendido por 11,6 millones de euros un...
# 19  CIENCIA\nEl Ministerio de Ciencia e Innovación...
# 20  CIENCIA\nAntes y después: esta visualización m...
# 21  CIENCIA\nUn cazador mata a tiros a una osa en ...
# 22  CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 23  CUMBRE VIEJA\nVolcán La Palma, última hora en ...
# 24  ENTREVISTA Mikel Artetxe\n"No hay que temer a ...
# 25  CIENCIA\nCuándo es el eclipse lunar de noviemb...
# 26  ASTRONOMÍA Cita con el cielo\nUn sutil eclipse...
# 27  CIENCIA\nCuándo es el eclipse lunar de noviemb...
# 28  CIENCIA\nMusk prevé primer vuelo orbital del S...
# 29  CIENCIA\nLeónidas 2021: el mejor momento para ...
# 30  CIENCIA\nLeónidas 2021: el mejor momento para ...
# 31  EXPLORACIÓN Estaba previsto para 2024\nEl regr...
# 32  ASTRONOMÍA Crónicas del Cosmos\nUna superburbu...
# 33  CUMBRE VIEJA\nJulio A., primer muerto en el vo...
# 34  EXPLORACIÓN\nMiura 1, el primer cohete 'Marca ...
# 35  GRANADA\nRegistran un terremoto de magnitud 2,...
# 36  CIENCIA\nMuere Winter, la delfín sin cola prot...
# 37  CIENCIA\nDespega la tercera misión comercial t...
# 38  CIENCIA\nEl avance de la lava del volcán de La...
# 39  CIENCIA\nUn grupo de niños descubre en Nueva Z...
# 40  CIENCIA\nCristal de olivino: el extraño minera...
# 41  ASTRONOMÍA Cita con el cielo\nEspectáculo plan...
# 42  DIRECTO\nVolcán La Palma, última hora en direc...
# 43  CORONAVIRUS\nAsí vigila la EMA los efectos sec...
# 44  DIRECTO\nVolcán La Palma, última hora en direc...
# 45  ERUPCIÓN EN LA PALMA Psicología de emergencia\...
# 46  CUMBRE VIEJA\nVolcán La Palma, última hora en ...
#
#                                           Entradillas  \
# 0   El volcán alcanza este sábado los 84 días de d...
# 1   El volcán alcanza este sábado los 84 días de d...
# 2   Hallan una pareja de agujeros negros supermasi...
# 3   Consulta el calendario lunar de diciembre 2021...
# 4   Los rastros fósiles analizados se localizan en...
# 5   Los datos sugieren que podría parar en las pró...
# 6   El vehículo lunar Yutu 2, que comenzó una expe...
# 7   El director del Observatorio de Vigilancia Vol...
# 8   El volcán de Cumbre Vieja está a sólo cuatro d...
# 9   Cuando el cono principal comenzó a dar señales...
# 10  El análisis preliminar de los datos que esboza...
# 11  La Palma ha registrado 25 terremotos desde la ...
# 12  Un nuevo análisis de unas misteriosas huellas ...
# 13  Tras dos semanas de caída, la erupción de La P...
# 14  Pasados 70 días desde el inicio de la erupción...
# 15  Se conocen 10.000 asteroides cercanos a la Tie...
# 16  Tras ser lanzada esta mañana a lomos de un coh...
# 17  Christie's asegura que el manuscrito de 54 pág...
# 18  Diana Morant anuncia que el año que viene habr...
# 19  La lava del volcán de La Palma ha cubierto 1.0...
# 20  Participaba en un cacería de jabalís y fue ata...
# 21  El volcán de La Palma supera este fin de seman...
# 22  Ha superado la emisión de 10 millones de metro...
# 23  Tras completar una revolucionaria tesis sobre ...
# 24  El eclipse lunar tendrá lugar el 19 de noviemb...
# 25  Será visible desde el norte de Europa, América...
# 26  El eclipse lunar tendrá lugar el 19 de noviemb...
# 27  "Vamos a intentar con suerte hacer una docena ...
# 28  La lluvia de estrellas de las Leónidas alcanza...
# 29  La lluvia de estrellas de las Leónidas alcanza...
# 30  Falta de dinero, una batalla judicial entre lo...
# 31  El 'Hubble' publica una nueva imagen de la eno...
# 32  Fuentes de la familia confirman que su cadáver...
# 33  La empresa española PLD Space desarrolla entre...
# 34  El seísmo ha tenido lugar a las 5:45 de este s...
# 35  Winter saltó a la fama con su conmovedora hist...
# 36  Aproximadamente 22 horas después del lanzamien...
# 37  La superficie afectada por la lava del volcán ...
# 38  Estos pingüinos medían 1,38 metros de alto, te...
# 39  Se trata de una piedra semipreciosa que durant...
# 40  Este fin de semana podremos ver a estos tres p...
# 41  La calidad del aire es extremadamente desfavor...
# 42  La agencia mantiene un estricto sistema de vig...
# 43  La erupción del volcán de La Palma continúa. S...
# 44  Los expertos advierten de la "dificultad añadi...
# 45  Los expertos de ese organismo basan su pronóst...
# 46  Con esta misión, la NASA quiere prepararse por...
#
#                                                Textos       Fechas Noticiario
# 0   Cumbre Vieja ¿Sin volcán en 2022? "Todos los i...  2021-12-11     ElMundo
# 1   Cumbre Vieja ¿Sin volcán en 2022? "Todos los i...  2021-12-11     ElMundo
# 2   Astronomía Una superburbuja en la Gran Nube de...  2021-12-11     ElMundo
# 3   Astronomía Cómo ver este sábado el eclipse sol...  2021-12-10     ElMundo
# 4   Algunas de las especies de dinosaurios más vel...  2021-12-10     ElMundo
# 5   Ciencia 80 días a ciegas frente al volcán: "Lo...  2021-12-10     ElMundo
# 6   Espacio Las primeras huellas de China en la Lu...  2021-12-09     ElMundo
# 7   PREMIUM\nTERESA GUERRERO\n@teresaguerrerof\nMa...  2021-12-08     ElMundo
# 8   Ciencia ¿Un volcán hasta Navidad? Los expertos...  2021-12-08     ElMundo
# 9   Ciencia Antes y después: esta visualización mu...  2021-12-06     ElMundo
# 10  En vivo Última hora del volcán\nLa erupción de...  2021-12-02     ElMundo
# 11  Erupción El futuro de un volcán 'gallego': "Ni...  2021-12-03     ElMundo
# 12  Australopithecus Los vecinos de Lucy\nHallazgo...  2021-12-01     ElMundo
# 13  Carmen López "Si hubiera un botón de apagado l...  2021-11-30     ElMundo
# 14  Ciencia Antes y después: esta visualización mu...  2021-11-30     ElMundo
# 15  Ciencia DART, la primera misión que intentará ...  2021-11-24     ElMundo
# 16  ÁNGEL DÍAZ\nMadrid\nE. AMADE Y A. MATILLA | IN...  2021-11-24     ElMundo
# 17  Un borrador del trabajo manuscrito sobre la Te...  2021-11-23     ElMundo
# 18  Presupuestos Los científicos serán "personal p...  2021-11-22     ElMundo
# 19  JUAN C. SÁNCHEZ\n@_JuanCsanchez_\nMadrid\nActu...  2021-11-22     ElMundo
# 20  Un cazador, que rastreaba jabalíes en los alre...  2021-11-21     ElMundo
# 21  La lava del volcán de La Palma ocupa ocho hect...  2021-11-22     ElMundo
# 22  El volcán de La Palma, que comenzó su erupción...  2021-11-21     ElMundo
# 23  Mikel Artetxe, científico del Facebook AI Rese...  2021-11-19     ElMundo
# 24  Astronomía Un sutil eclipse de Luna al amanece...  2021-11-18     ElMundo
# 25  Guía Cuándo es el eclipse lunar de noviembre 2...  2021-11-18     ElMundo
# 26  Astronomía Un sutil eclipse de Luna al amanece...  2021-11-18     ElMundo
# 27  Elon Musk ha dicho este miércoles que el cohet...  2021-11-18     ElMundo
# 28  Ciencia Eclipse lunar de noviembre: cuándo es ...  2021-11-17     ElMundo
# 29  Ciencia Eclipse lunar de noviembre: cuándo es ...  2021-11-17     ElMundo
# 30  Especial EEUU planea volver a la Luna\nLas vac...  2021-11-16     ElMundo
# 31  Astronomía Cuarenta y dos asteroides vistos co...  2021-11-14     ElMundo
# 32  Se llamaba Julio A.C., tenía 72 años, había tr...  2021-11-13     ElMundo
# 33  Misiones La nueva carrera espacial: traer roca...  2021-11-13     ElMundo
# 34  El Instituto Geográfico Nacional (IGN) ha regi...  2021-11-13     ElMundo
# 35  "Con el corazón apesadumbrado, Clearwater Mari...  2021-11-12     ElMundo
# 36  La tercera misión comercial tripulada de la NA...  2021-11-11     ElMundo
# 37  JUAN C. SÁNCHEZ\n(Mapa)\n@_JuanCsanchez_\nEFE\...  2021-11-09     ElMundo
# 38  España La ley de bienestar animal reconvertirá...  2021-11-09     ElMundo
# 39  En vivo Sigue las últimas novedades del volcán...  2021-11-08     ElMundo
# 40  Astronomía Cuarenta y dos asteroides vistos co...  2021-11-07     ElMundo
# 41  Historias Cincuenta 'domingos' de ceniza: "Me ...  2021-11-08     ElMundo
# 42  En directo Coronavirus, últimas noticias de ho...  2021-11-06     ElMundo
# 43  Volcán La especulación devora La Palma tras el...  2021-11-07     ElMundo
# 44  En directo Volcán en La Palma, última hora\nHi...  2021-11-05     ElMundo
# 45  Cumbre Vieja El 'Fernando Simón' del volcán qu...  2021-11-06     ElMundo
# 46  Ciencia La primera expedición cinematográfica ...  2021-11-05     ElMundo

# %%
n_Noticia = 0
for i in df.index:
    nombreFichero = "Ciencia_"+ df["Fechas"][i] + df["Noticiario"][i] + str(n_Noticia)
    file = open(nombreFichero, "w")
    file.write(df["Titulos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Entradillas"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Textos"][i]+ "\n")
    file.write("############################################ \n")
    file.write(df["Fechas"][i]+ "\n")
    sleep(0.5)
    file.close()
    
    n_Noticia += 1

# %% [markdown]
# ## WebScraping ElPais-Sanidad

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://elpais.com/noticias/sanidad/')
sleep(1.5)

listaNoticiasSanidad_P = driver.find_elements(By.XPATH, '//a[@class="c_m_c _pr _db"]')

linkNoticiasSanidad_P = list()

for noticia in listaNoticiasSanidad_P:
    
    linkSanidad_P = noticia.get_attribute('href')
    linkNoticiasSanidad_P.append(linkSanidad_P)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Pablo\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_15524/1786775611.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
titulosSanidad_P = list()
entradillasSanidad_P = list()
textosSanidad_P = list()
fechasSanidad_P = list()

for i in linkNoticiasSanidad_P:
    
    try:
        driver.get(i)
        titulo = driver.find_element(By.XPATH, '//h1[@class="a_t"]').text
        titulosSanidad_P.append(titulo)
        entradilla = driver.find_element(By.XPATHTH, '//h2[@class="a_st"]').text
        entradillasSanidad_P.append(entradilla)
        texto = driver.find_element(By.XPATH, '//div[@class="a_c clearfix"]').text
        textosSanidad_P.append(texto)
        fecha = driver.find_element(By.ID, 'article_date_p').get_attribute('data-date')
        fechasSanidad_P.append(fecha)
        
        sleep(0.5)
    except:
        continue

# %%
df_P = pd.DataFrame(list(zip(titulosSanidad_P, entradillasSanidad_P, textosSanidad_P, fechasSanidad_P)), columns = ['Titulos','Entradillas', 'Textos', 'Fechas'])
df_P=df_P.assign(Noticiario= "ElPais")

df_P["Fechas"] = df_P["Fechas"].replace(to_replace ='[T]\d*\:\d{2}\:\d{2}[Z]', value = ' ', regex = True)
df_P
# Out:
# Empty DataFrame
# Columns: [Titulos, Entradillas, Textos, Fechas, Noticiario]
# Index: []

# %% [markdown]
# ## Salud 20minutos

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.20minutos.es/salud/')
sleep(1.5)

listaNoticiasSalud_20m = driver.find_elements(By.XPATH, '//div[@class="media-content"]')

linkNoticiasSalud_20m = list()

for noticia in listaNoticiasSalud_20m:
    bLink = noticia.find_element(By.TAG_NAME, 'a')
    linkSalud_20m = bLink.get_attribute('href')
    linkNoticiasSalud_20m.append(linkSalud_20m)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\34674\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
for i in linkNoticiasSalud_20m:
    print(i)
# Out:
# https://www.20minutos.es/salud/nutricion/riesgos-tomar-cafe-restos-horas-moho-leche-4920253/
# https://www.20minutos.es/salud/esta-es-fiabilidad-hacerse-test-antigenos-antes-cena-navidad-4920651/
# https://www.20minutos.es/salud/actualidad/bacteria-helicobapter-pylori-resistencia-antibioticos-4921058/
# https://www.20minutos.es/salud/medicina/obesidad-y-deterioro-cognitivo-que-relacion-tienen-4914963/
# https://www.20minutos.es/salud/en-que-se-diferencia-dosis-vacuna-covid-ninos-y-adultos-4920561/
# https://www.20minutos.es/videos/salud/el-cirujano-gallego-que-triunfa-en-123-paises-con-su-tecnica-para-el-cancer-de-pulmon-4913358/
# https://www.20minutos.es/videos/salud/los-nuevos-precios-de-los-medicamentos-cuales-suben-y-cuales-bajan-4912623/
# https://www.20minutos.es/videos/salud/estos-son-los-mitos-arraigados-sobre-los-resfriados-en-los-ninos-4908576/
# https://www.20minutos.es/salud/familia/cuanto-deberia-durar-sexo-tiempo-ciencia-4879688/
# https://www.20minutos.es/salud/familia/sexo-como-combatir-la-disfuncion-erectil-4884310/
# https://www.20minutos.es/salud/familia/ayuda-el-teletrabajo-a-mejorar-la-vida-sexual-de-las-personas-4866990/
# https://www.20minutos.es/salud/nutricion/trastornos-conducta-alimentaria-resistencia-tratamiento-4909809/
# https://www.20minutos.es/salud/medicina/lo-que-nos-dicen-las-alucinaciones-darles-la-importancia-adecuada-es-etico-y-terapeutico-4893484/
# https://www.20minutos.es/salud/maria-tras-intentar-quitarse-vida-no-solo-siempre-gente-dispuesta-ayudarte-4907266/
# https://www.20minutos.es/salud/nutricion/las-redes-sociales-y-su-papel-en-el-aumento-de-casos-de-trastornos-de-la-conducta-alimentaria-tac-4909715/

# %%
titulosSalud_20m = list()
entradillasSalud_20m = list()
textosSalud_20m = list()
fechasSalud_20m = list()

for i in linkNoticiasSalud_20m:
    
    try:
        driver.get(i)
        titulo = driver.find_element(By.XPATH, '//h1[@class="article-title "]').text
        titulosSalud_20m.append(titulo)
        entradilla = driver.find_element(By.XPATHTH, '//div[@class="article-intro "]').text
        entradillasSalud_20m.append(entradilla)
        texto = driver.find_elements(By.XPATH, '//p[@class="paragraph "]').text
        textosSalud_20m.append(texto)
        fecha = driver.find_element(By.XPATH, 'span[@class="article-date"]').text
        fechasSalud_20m.append(fecha)
        
        sleep(0.5)
    except:
        continue

# %%
for i in titulosSalud_20m:
    print(i)
# Out:
# Por qué no debes tomar café hecho unas horas antes: cuidado con el moho y la leche
# Esta es la fiabilidad de hacerse un test de antígenos antes de una cena de Navidad
# La bacteria Helicobacter pylori tiene una gran resistencia a los antibióticos, según un estudio
# Obesidad y deterioro cognitivo. ¿Qué relación tienen?
# En qué se diferencia la dosis de la vacuna covid de los niños con la de los adultos
# El cirujano gallego que triunfa en 123 países con su técnica para el cáncer de pulmón
# Los nuevos precios de los medicamentos: ¿cuáles suben y cuáles bajan?
# Estos son los mitos arraigados sobre los resfriados en los niños
# Cuánto debería durar el sexo: este sería el tiempo adecuado, según la ciencia
# Cómo combatir la disfunción eréctil
# ¿Ayuda el teletrabajo a mejorar la vida sexual de las personas?
# Una de cada cuatro personas con Trastornos de la Conducta Alimentaria es resistente al tratamiento
# Lo que se esconde tras las alucinaciones y por qué aparecen en personas sanas
# María cuenta su recuperación tras intentar quitarse la vida: "No estás solo. Siempre hay gente dispuesta a ayudarte"
# Las redes sociales y su papel en el aumento de casos de Trastornos de la Conducta Alimentaria

# %%
for i in titulosSalud_20m:
    print(i)
# Out:
# Por qué no debes tomar café hecho unas horas antes: cuidado con el moho y la leche
# Esta es la fiabilidad de hacerse un test de antígenos antes de una cena de Navidad
# La bacteria Helicobacter pylori tiene una gran resistencia a los antibióticos, según un estudio
# Obesidad y deterioro cognitivo. ¿Qué relación tienen?
# En qué se diferencia la dosis de la vacuna covid de los niños con la de los adultos
# El cirujano gallego que triunfa en 123 países con su técnica para el cáncer de pulmón
# Los nuevos precios de los medicamentos: ¿cuáles suben y cuáles bajan?
# Estos son los mitos arraigados sobre los resfriados en los niños
# Cuánto debería durar el sexo: este sería el tiempo adecuado, según la ciencia
# Cómo combatir la disfunción eréctil
# ¿Ayuda el teletrabajo a mejorar la vida sexual de las personas?
# Una de cada cuatro personas con Trastornos de la Conducta Alimentaria es resistente al tratamiento
# Lo que se esconde tras las alucinaciones y por qué aparecen en personas sanas
# María cuenta su recuperación tras intentar quitarse la vida: "No estás solo. Siempre hay gente dispuesta a ayudarte"
# Las redes sociales y su papel en el aumento de casos de Trastornos de la Conducta Alimentaria
